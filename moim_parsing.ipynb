# %%
import time
import csv
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from datetime import datetime

driver = webdriver.Chrome('./chromedriver')

# %%
links = []
for i in range(1, 10):
    driver.get('https://www.frip.co.kr/daily/social/hot?page='+ str(i))
    time.sleep(1)
    lectures = driver.find_elements_by_class_name("sc-kGXeez")
    for lecture in lectures:
        a_name = lecture.find_element_by_tag_name('a').get_attribute('href')
        links.append(a_name)

# %%
dataframe = pd.DataFrame(links)
dataframe.to_csv('./moim.csv', header=False,index=False)

# %%
df = pd.read_csv('./moim.csv', header=None)
new_links = list(df[0])

# %%
import pandas as pd
from datetime import datetime

meeting_columns = (
    "meeting_id",
    "uid",
    "writer",
    "created_at",
    "updated_at",
    "is_period",
    "meeting_date",
    "period_date",
    "is_class",
    "max_person",
    "now_person",
    "content",
    "ref_url",
    "address",
    "fee",
    "unit",
    "is_active",
    "like_cnt",
    "view_cnt",
    "score",
    "main_category",
    "tags"
)

image_columns = (
    "meeting_id",
    "image_url"
)

# %%
meetings = []
images = []

# %%
driver.get('https://www.frip.co.kr/products/135944')

# %%
images_link = driver.find_elements_by_class_name('cljRKC')
image_urls = set()
for i in images_link:
    image_urls.add(i.get_attribute('src'))
image_url = ' '.join(image_urls)
print(image_url)
# Out:
# https://res.cloudinary.com/frientrip/image/upload/ar_4:3,c_fill,dpr_2.0,f_auto,g_auto,q_auto,r_0,w_930/1590056422855_khlgpt https://res.cloudinary.com/frientrip/image/upload/ar_4:3,c_fill,dpr_2.0,f_auto,g_auto,q_auto,r_0,w_930/1589966724220_ojhgw5

# %%
for link in range(len(new_links)):
    print(new_links[link])
    driver.get(new_links[link])
    time.sleep(2)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    meeting_id = new_links[link].split('/')[-1]
    uid = driver.find_element_by_class_name('nCgAM').find_element_by_tag_name('a').get_attribute('href')
    writer = soup.select_one('span.gYdgbL')[1:-1]
    created_at = datetime.now()
    updated_at = datetime.now()
    is_period = 0
    meeting_date = datetime.now()
    temp = soup.select('section.sc-dUcZlc > div.sc-ZUflv > div.sc-esoVGF')
    if temp[-3].text == '':
        continue
    elif temp[-3].text[0].isdigit():
        temp_date = ''
        for t in temp[1].text:
            if t == '외':
                break
            if t in '(월화수목금토일요일년)':
                continue
            if t == ' ':
                t = '-'
            temp_date += t
        temp_date = temp_date[:-1]
        meeting_date = datetime.strptime(temp_date, '%Y-%m-%d-%H:%M')
    period_date = ''
    is_class = 1
    max_person = 20
    now_person = 1
    content = '[내용]' + soup.select('div.cSNowP')[0].text
    ref_url = new_links[link]
    print(soup.select_one('div.sc-kRCAcj').text[:-5])
    address = soup.select_one('div.sc-kRCAcj').text[:-5]
    fee = soup.select_one('div.sc-eBipZS').text[:-1].replace(',', '')
    unit = '원'
    is_active = 1
    like_temp = ''
    for t in temp[0].text:
        if not t.isdigit():
            break
        like_temp += t
    like_cnt = int(like_temp)
    view_cnt = 0
    score = 0
    if temp[-1].text[6].isdigit():
        score = float(temp[-1].text[6:])
    main_category = 0
    tags = ''
    
    # 이미지 저장
    images_link = driver.find_elements_by_class_name('cljRKC')
    image_urls = set()
    for i in images_link:
        image_urls.add(i.get_attribute('src'))
    image_url = ' '.join(image_urls)
    
    # 데이터 저장
    meetings.append(
    [
        meeting_id,
        uid,
        writer,
        created_at,
        updated_at,
        is_period,
        meeting_date,
        period_date,
        is_class,
        max_person,
        now_person,
        content,
        ref_url,
        address,
        fee,
        unit,
        is_active,
        like_cnt,
        view_cnt,
        score,
        main_category,
        tags
    ]
        
    images.append(
    [
        meeting_id,
        image_url
    ]
    )
)
# Out:
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/136047
# 한양도성 낙산
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/121871
# 서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/134285
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135990
# 서울 강남구 선릉로64길 28, 메리제인 플라워카페

# %%
meeting_frame = pd.DataFrame(data=meetings, columns=meeting_columns)

# %%
meeting_frame
# Out:
#     meeting_id                                 uid      writer  \
# 0       131010   https://www.frip.co.kr/hosts/9961   [그루터기 :)]
# 1       135944  https://www.frip.co.kr/hosts/11510       [데이지]
# 2       114488   https://www.frip.co.kr/hosts/2331        [동네]
# 3       128459   https://www.frip.co.kr/hosts/7774       [필카맨]
# 4       125653   https://www.frip.co.kr/hosts/7542        [시아]
# ..         ...                                 ...         ...
# 175     121871   https://www.frip.co.kr/hosts/2331        [동네]
# 176     133315   https://www.frip.co.kr/hosts/8873        [록담]
# 177     134285  https://www.frip.co.kr/hosts/11034  [달리는 농구힐러]
# 178     128061   https://www.frip.co.kr/hosts/5493     [에스프레소]
# 179     135990   https://www.frip.co.kr/hosts/5493     [에스프레소]
#
#                     created_at                 updated_at  is_period  \
# 0   2020-05-22 17:19:49.357696 2020-05-22 17:19:49.357696          0
# 1   2020-05-22 17:19:53.094697 2020-05-22 17:19:53.094697          0
# 2   2020-05-22 17:19:57.035698 2020-05-22 17:19:57.035698          0
# 3   2020-05-22 17:20:01.199697 2020-05-22 17:20:01.199697          0
# 4   2020-05-22 17:20:05.061699 2020-05-22 17:20:05.061699          0
# ..                         ...                        ...        ...
# 175 2020-05-22 17:30:23.296223 2020-05-22 17:30:23.296223          0
# 176 2020-05-22 17:30:26.694225 2020-05-22 17:30:26.694225          0
# 177 2020-05-22 17:30:30.185224 2020-05-22 17:30:30.185224          0
# 178 2020-05-22 17:30:33.660224 2020-05-22 17:30:33.660224          0
# 179 2020-05-22 17:30:37.071224 2020-05-22 17:30:37.071224          0
#
#                   meeting_date period_date  is_class  max_person  ...  \
# 0   2020-05-28 19:30:00.000000                     1          20  ...
# 1   2020-05-25 19:00:00.000000                     1          20  ...
# 2   2020-05-26 19:00:00.000000                     1          20  ...
# 3   2020-05-30 15:00:00.000000                     1          20  ...
# 4   2020-05-22 17:20:05.061699                     1          20  ...
# ..                         ...         ...       ...         ...  ...
# 175 2020-05-29 19:30:00.000000                     1          20  ...
# 176 2020-06-01 00:00:00.000000                     1          20  ...
# 177 2020-06-01 00:00:00.000000                     1          20  ...
# 178 2020-05-29 19:45:00.000000                     1          20  ...
# 179 2020-05-31 16:00:00.000000                     1          20  ...
#
#                                     ref_url  \
# 0    https://www.frip.co.kr/products/131010
# 1    https://www.frip.co.kr/products/135944
# 2    https://www.frip.co.kr/products/114488
# 3    https://www.frip.co.kr/products/128459
# 4    https://www.frip.co.kr/products/125653
# ..                                      ...
# 175  https://www.frip.co.kr/products/121871
# 176  https://www.frip.co.kr/products/133315
# 177  https://www.frip.co.kr/products/134285
# 178  https://www.frip.co.kr/products/128061
# 179  https://www.frip.co.kr/products/135990
#
#                                   address    fee unit is_active like_cnt  \
# 0                서울시 동작구 동작대로1길 10-4, 카페무  16900    원         1      743
# 1                   서울 마포구 연남동 487-135 2층  30000    원         1       43
# 2    여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단   5000    원         1     4322
# 3               서울 강남구 테헤란로33길 7 바른커피 역삼점  25000    원         1     1187
# 4                  서울시 중구 세종대로 89, 3층 스패뉴  39000    원         1     1622
# ..                                    ...    ...  ...       ...      ...
# 175        서울시 송파구 올림픽로 지하 265, 잠실역 1번 출구   5000    원         1     1071
# 176                              온라인에서 진행  30000    원         1      138
# 177                              온라인에서 진행  30000    원         1      127
# 178         서울시 강남구 선릉로64길 28, 메리제인 플라워카페  20000    원         1      165
# 179          서울 강남구 선릉로64길 28, 메리제인 플라워카페  20000    원         1        9
#
#      view_cnt  score  main_category  tags
# 0           0   4.44              0
# 1           0   0.00              0
# 2           0   4.65              0
# 3           0   4.50              0
# 4           0   4.59              0
# ..        ...    ...            ...   ...
# 175         0   4.90              0
# 176         0   4.64              0
# 177         0   5.00              0
# 178         0   4.96              0
# 179         0   0.00              0
#
# [180 rows x 22 columns]

# %%
print(new_links[link])
driver.get(new_links[link])
time.sleep(2)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
meeting_id = new_links[link].split('/')[-1]
uid = driver.find_element_by_class_name('nCgAM').find_element_by_tag_name('a').get_attribute('href')
writer = soup.select_one('span.gYdgbL')
created_at = datetime.now()
updated_at = datetime.now()
is_period = 0
meeting_date = datetime.now()
temp = soup.select('section.sc-dUcZlc > div.sc-ZUflv > div.sc-esoVGF')
if temp[1].text == '':
    continue
elif temp[1].text[0].isdigit():
    temp_date = ''
    for t in temp[1].text:
        if t == '외':
            break
        if t in '(월화수목금토일요일년)':
            continue
        if t == ' ':
            t = '-'
        temp_date += t
    temp_date = temp_date[:-1]
    meeting_date = datetime.strptime(temp_date, '%Y-%m-%d-%H:%M')
period_date = ''
is_class = 1
max_person = 20
now_person = 1
content = '[내용]' + soup.select('div.cSNowP')[0].text
ref_url = new_links[link]
print(soup.select_one('div.sc-kRCAcj').text[:-5])
address = soup.select_one('div.sc-kRCAcj').text[:-5]
fee = soup.select_one('div.sc-eBipZS').text[:-1].replace(',', '')
unit = '원'
is_active = 1
like_temp = ''
for t in temp[0].text:
    if not t.isdigit():
        break
    like_temp += t
like_cnt = int(like_temp)
view_cnt = 0
score = 0
if temp[-1].text[6].isdigit():
    score = float(temp[-1].text[6:])
main_category = 0
tags = ''

# 데이터 저장
meetings.append(
[
    meeting_id,
    uid,
    writer,
    created_at,
    updated_at,
    is_period,
    meeting_date,
    period_date,
    is_class,
    max_person,
    now_person,
    content,
    ref_url,
    address,
    fee,
    unit,
    is_active,
    like_cnt,
    view_cnt,
    score,
    main_category,
    tags
]
)
