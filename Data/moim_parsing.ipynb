# %%
import time
import csv
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from datetime import datetime

driver = webdriver.Chrome('./chromedriver')

# %%
links = []
for i in range(1, 10):
    driver.get('https://www.frip.co.kr/daily/social/hot?page='+ str(i))
    time.sleep(1)
    lectures = driver.find_elements_by_class_name("sc-kGXeez")
    for lecture in lectures:
        a_name = lecture.find_element_by_tag_name('a').get_attribute('href')
        links.append(a_name)

# %%
dataframe = pd.DataFrame(links)
dataframe.to_csv('./moim.csv', header=False,index=False)

# %%
df = pd.read_csv('./moim.csv', header=None)
new_links = list(df[0])

# %%
import pandas as pd
from datetime import datetime

meeting_columns = (
    "meeting_id",
    "uid",
    "writer",
    "created_at",
    "updated_at",
    "is_period",
    "meeting_date",
    "period_date",
    "is_class",
    "max_person",
    "now_person",
    "content",
    "ref_url",
    "address",
    "fee",
    "unit",
    "is_active",
    "like_cnt",
    "view_cnt",
    "score",
    "main_category",
    "tags"
)

image_columns = (
    "meeting_id",
    "image_url"
)

# %%
meetings = []
images = []

# %%
driver.get('https://www.frip.co.kr/products/135944')

# %%
images_link = driver.find_elements_by_class_name('cljRKC')
image_urls = set()
for i in images_link:
    image_urls.add(i.get_attribute('src'))
image_url = ' '.join(image_urls)
print(image_url)
# Out:
# https://res.cloudinary.com/frientrip/image/upload/ar_4:3,c_fill,dpr_2.0,f_auto,g_auto,q_auto,r_0,w_930/1590056422855_khlgpt https://res.cloudinary.com/frientrip/image/upload/ar_4:3,c_fill,dpr_2.0,f_auto,g_auto,q_auto,r_0,w_930/1589966724220_ojhgw5

# %%
for link in range(len(new_links)):
    print(new_links[link])
    driver.get(new_links[link])
    time.sleep(2)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    meeting_id = new_links[link].split('/')[-1]
    uid = driver.find_element_by_class_name('nCgAM').find_element_by_tag_name('a').get_attribute('href')
    writer = soup.select_one('span.gYdgbL')
    created_at = datetime.now()
    updated_at = datetime.now()
    is_period = 0
    meeting_date = datetime.now()
    temp = soup.select('section.sc-dUcZlc > div.sc-ZUflv > div.sc-esoVGF')
    if temp[-3].text == '':
        continue
    elif temp[-3].text[0].isdigit():
        temp_date = ''
        for t in temp[1].text:
            if t == '외':
                break
            if t in '(월화수목금토일요일년)':
                continue
            if t == ' ':
                t = '-'
            temp_date += t
        temp_date = temp_date[:-1]
        meeting_date = datetime.strptime(temp_date, '%Y-%m-%d-%H:%M')
    period_date = ''
    is_class = 1
    max_person = 20
    now_person = 1
    content = '[내용]' + soup.select('div.cSNowP')[0].text
    ref_url = new_links[link]
    print(soup.select_one('div.sc-kRCAcj').text[:-5])
    address = soup.select_one('div.sc-kRCAcj').text[:-5]
    fee = soup.select_one('div.sc-eBipZS').text[:-1].replace(',', '')
    unit = '원'
    is_active = 1
    like_temp = ''
    for t in temp[0].text:
        if not t.isdigit():
            break
        like_temp += t
    like_cnt = int(like_temp)
    view_cnt = 0
    score = 0
    if temp[-1].text[6].isdigit():
        score = float(temp[-1].text[6:])
    main_category = 0
    tags = ''
    
    # 이미지 저장
    images_link = driver.find_elements_by_class_name('cljRKC')
    image_urls = set()
    for i in images_link:
        image_urls.add(str(i.get_attribute('src')))
    image_url = ' '.join(image_urls)
    
    # 데이터 저장
    meetings.append(
    [
        meeting_id,
        uid,
        writer,
        created_at,
        updated_at,
        is_period,
        meeting_date,
        period_date,
        is_class,
        max_person,
        now_person,
        content,
        ref_url,
        address,
        fee,
        unit,
        is_active,
        like_cnt,
        view_cnt,
        score,
        main_category,
        tags
    ]
    )
        
    images.append(
    [
        meeting_id,
        image_url
    ]
    )
# Out:
# https://www.frip.co.kr/products/135944
# 서울 마포구 연남동 487-135 2층
# https://www.frip.co.kr/products/131010
# 서울시 동작구 동작대로1길 10-4, 카페무
# https://www.frip.co.kr/products/135855
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/108252
# 서울시 강남구 선릉로64길 28 카페 메리제인
# https://www.frip.co.kr/products/125653
# 서울시 중구 세종대로 89, 3층 스패뉴
# https://www.frip.co.kr/products/128459
# 서울 강남구 테헤란로33길 7 바른커피 역삼점
# https://www.frip.co.kr/products/133413
# 서울시 강남구 학동로30길 45 힐하우스 3층
# https://www.frip.co.kr/products/123368
# 서울시 서초구 양재동 265-24, 4층
# https://www.frip.co.kr/products/126020
# 경기도 가평군 상면 축령로45번길 100, 팝콘하우스
# https://www.frip.co.kr/products/135118
# 서울 강남구 봉은사로 68길 21, 2층 루이스바 (삼성중앙역 7번출구)
# https://www.frip.co.kr/products/114488
# 여의나루역 3번출구 -> 미니스톱 끝에서 왼쪽 -> 한강가는 계단
# https://www.frip.co.kr/products/134289
# 온라인에서 진행
# https://www.frip.co.kr/products/132195
# 서울숲
# https://www.frip.co.kr/products/133315
# 온라인에서 진행
# https://www.frip.co.kr/products/128061
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/135609
# 서울 마포구 동교로24길 17 3층 이코노미스타
# https://www.frip.co.kr/products/134752
# 서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)
# https://www.frip.co.kr/products/133251
# 생활은 일상에서, 칭찬은 카카오톡에서 진행
# https://www.frip.co.kr/products/128055
# 서울시 강남구 선릉로64길 28, 메리제인 플라워카페
# https://www.frip.co.kr/products/134763
# 서울 마포구 광성로 36 Boston Coffee <1층>

# %%
meeting_frame = pd.DataFrame(data=meetings, columns=meeting_columns)

# %%
meeting_frame
# Out:
#     meeting_id                                 uid     writer  \
# 0       135944  https://www.frip.co.kr/hosts/11510      [데이지]
# 1       131010   https://www.frip.co.kr/hosts/9961  [그루터기 :)]
# 2       135855   https://www.frip.co.kr/hosts/7542       [시아]
# 3       108252   https://www.frip.co.kr/hosts/5493    [에스프레소]
# 4       125653   https://www.frip.co.kr/hosts/7542       [시아]
# ..         ...                                 ...        ...
# 175     135609  https://www.frip.co.kr/hosts/11305      [박초롱]
# 176     134752  https://www.frip.co.kr/hosts/11160      [아페리]
# 177     133251  https://www.frip.co.kr/hosts/10766     [수오재기]
# 178     128055   https://www.frip.co.kr/hosts/5493    [에스프레소]
# 179     134763   https://www.frip.co.kr/hosts/3390    [아메리카노]
#
#                     created_at                 updated_at  is_period  \
# 0   2020-05-24 23:49:39.348757 2020-05-24 23:49:39.348757          0
# 1   2020-05-24 23:49:43.568305 2020-05-24 23:49:43.568305          0
# 2   2020-05-24 23:49:47.769308 2020-05-24 23:49:47.769308          0
# 3   2020-05-24 23:49:51.927158 2020-05-24 23:49:51.927158          0
# 4   2020-05-24 23:49:55.852370 2020-05-24 23:49:55.852370          0
# ..                         ...                        ...        ...
# 175 2020-05-24 23:59:56.637987 2020-05-24 23:59:56.637987          0
# 176 2020-05-24 23:59:59.748122 2020-05-24 23:59:59.748122          0
# 177 2020-05-25 00:00:03.899047 2020-05-25 00:00:03.899047          0
# 178 2020-05-25 00:00:07.198502 2020-05-25 00:00:07.198502          0
# 179 2020-05-25 00:00:10.563679 2020-05-25 00:00:10.563679          0
#
#                   meeting_date period_date  is_class  max_person  ...  \
# 0   2020-05-25 19:00:00.000000                     1          20  ...
# 1   2020-05-28 19:30:00.000000                     1          20  ...
# 2   2020-05-24 23:49:47.769308                     1          20  ...
# 3   2020-05-30 18:00:00.000000                     1          20  ...
# 4   2020-05-24 23:49:55.852370                     1          20  ...
# ..                         ...         ...       ...         ...  ...
# 175 2020-06-09 19:30:00.000000                     1          20  ...
# 176 2020-06-06 19:00:00.000000                     1          20  ...
# 177 2020-06-01 00:00:00.000000                     1          20  ...
# 178 2020-05-29 19:45:00.000000                     1          20  ...
# 179 2020-05-29 19:30:00.000000                     1          20  ...
#
#                                     ref_url  \
# 0    https://www.frip.co.kr/products/135944
# 1    https://www.frip.co.kr/products/131010
# 2    https://www.frip.co.kr/products/135855
# 3    https://www.frip.co.kr/products/108252
# 4    https://www.frip.co.kr/products/125653
# ..                                      ...
# 175  https://www.frip.co.kr/products/135609
# 176  https://www.frip.co.kr/products/134752
# 177  https://www.frip.co.kr/products/133251
# 178  https://www.frip.co.kr/products/128055
# 179  https://www.frip.co.kr/products/134763
#
#                                 address     fee unit is_active like_cnt  \
# 0                 서울 마포구 연남동 487-135 2층   30000    원         1      103
# 1              서울시 동작구 동작대로1길 10-4, 카페무   16900    원         1      768
# 2                서울시 중구 세종대로 89, 3층 스패뉴   39000    원         1      139
# 3             서울시 강남구 선릉로64길 28 카페 메리제인   20000    원         1     1946
# 4                서울시 중구 세종대로 89, 3층 스패뉴   39000    원         1     1633
# ..                                  ...     ...  ...       ...      ...
# 175          서울 마포구 동교로24길 17 3층 이코노미스타  149000    원         1       53
# 176  서울시 중구 을지로2가 199-46, 층일빌딩 3층(일마지오)   38000    원         1       97
# 177             생활은 일상에서, 칭찬은 카카오톡에서 진행   10000    원         1       57
# 178       서울시 강남구 선릉로64길 28, 메리제인 플라워카페   20000    원         1      407
# 179    서울 마포구 광성로 36 Boston Coffee <1층>   15000    원         1       71
#
#      view_cnt  score  main_category  tags
# 0           0   0.00              0
# 1           0   4.50              0
# 2           0   5.00              0
# 3           0   4.63              0
# 4           0   4.60              0
# ..        ...    ...            ...   ...
# 175         0   0.00              0
# 176         0   0.00              0
# 177         0   4.90              0
# 178         0   4.71              0
# 179         0   4.71              0
#
# [180 rows x 22 columns]

# %%
meeting_frame.to_csv('./moim_data.csv', header=True,index=False, encoding='utf-8')

# %%
print(new_links[link])
driver.get(new_links[link])
time.sleep(2)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
meeting_id = new_links[link].split('/')[-1]
uid = driver.find_element_by_class_name('nCgAM').find_element_by_tag_name('a').get_attribute('href')
writer = soup.select_one('span.gYdgbL')
created_at = datetime.now()
updated_at = datetime.now()
is_period = 0
meeting_date = datetime.now()
temp = soup.select('section.sc-dUcZlc > div.sc-ZUflv > div.sc-esoVGF')
if temp[1].text == '':
    continue
elif temp[1].text[0].isdigit():
    temp_date = ''
    for t in temp[1].text:
        if t == '외':
            break
        if t in '(월화수목금토일요일년)':
            continue
        if t == ' ':
            t = '-'
        temp_date += t
    temp_date = temp_date[:-1]
    meeting_date = datetime.strptime(temp_date, '%Y-%m-%d-%H:%M')
period_date = ''
is_class = 1
max_person = 20
now_person = 1
content = '[내용]' + soup.select('div.cSNowP')[0].text
ref_url = new_links[link]
print(soup.select_one('div.sc-kRCAcj').text[:-5])
address = soup.select_one('div.sc-kRCAcj').text[:-5]
fee = soup.select_one('div.sc-eBipZS').text[:-1].replace(',', '')
unit = '원'
is_active = 1
like_temp = ''
for t in temp[0].text:
    if not t.isdigit():
        break
    like_temp += t
like_cnt = int(like_temp)
view_cnt = 0
score = 0
if temp[-1].text[6].isdigit():
    score = float(temp[-1].text[6:])
main_category = 0
tags = ''

# 데이터 저장
meetings.append(
[
    meeting_id,
    uid,
    writer,
    created_at,
    updated_at,
    is_period,
    meeting_date,
    period_date,
    is_class,
    max_person,
    now_person,
    content,
    ref_url,
    address,
    fee,
    unit,
    is_active,
    like_cnt,
    view_cnt,
    score,
    main_category,
    tags
]
)

# %%
image_frame = pd.DataFrame(data=images, columns=image_columns)
image_frame.to_csv('./moim_images.csv', header=True,index=False, encoding='utf-8')
image_frame
